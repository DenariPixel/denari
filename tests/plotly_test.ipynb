# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../denari'))

from denari import TaxTools as tax
import plotly.graph_objects as go
# Out:
# ['TaxTools', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'dt', 'go', 'np', 'os', 'pd']

# %%
dir(tax)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'adjust_allowance',
#  'adjust_ni_band',
#  'corporate_ni',
#  'corporation_tax',
#  'create_dividend_table',
#  'create_student_loan_table',
#  'create_table',
#  'dividend_tax',
#  'employee_ni',
#  'get_law',
#  'income_tax',
#  'interpret_single_df_value',
#  'interpret_tax_code_allowance',
#  'interpret_tax_code_ni_band',
#  'iterate_full_take',
#  'iterate_lite_full_take',
#  'iterate_salaries',
#  'ltd_full_take',
#  'marginal',
#  'marginalise',
#  'optimal_iterations',
#  'optimal_take',
#  'replace_threshold_rates',
#  'salary_taxes',
#  'student_loans',
#  'tax_year']

# %%
t = 40000
e = 3000
y = '2021/2022'
tc = '1257A'

# %%
# %%time
a = tax.iterate_lite_full_take(t,e,y,tc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:1
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\denari\TaxTools.py:604, in TaxTools.iterate_lite_full_take(turnover, expenses, tax_year, tax_code, student_loan_plan, student_loan_second_plan, optimal)
#     601 turnover_deduct_expenses = turnover - expenses
#     602 iteration_step = TaxTools.optimal_iterations(turnover_deduct_expenses)
# --> 604 initial_scenarios = TaxTools.iterate_salaries(turnover, 0, turnover_deduct_expenses, expenses, tax_year, tax_code, student_loan_plan, student_loan_second_plan, iteration_step)
#     605 optimal_row = initial_scenarios.index[initial_scenarios['Total Takehome'] == initial_scenarios['Total Takehome'].max()].tolist()
#     606 optimal_range = [*range(optimal_row[0] - 1, optimal_row[0] + 2)]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\denari\TaxTools.py:552, in TaxTools.iterate_salaries(turnover, min_salary, max_salary, expenses, tax_year, tax_code, student_loan_plan, student_loan_second_plan, iteration_step)
#     549 results = pd.DataFrame()
#     551 for salary in range(min_salary, max_salary + 1, iteration_step):
# --> 552     salary_data = TaxTools.ltd_owner_full_take(turnover, salary, expenses, tax_year, tax_code, student_loan_plan, student_loan_second_plan)
#     553     results = pd.concat([results, salary_data])
#     555 results = results.reset_index(drop=True)
#
# AttributeError: type object 'TaxTools' has no attribute 'ltd_owner_full_take'

# %%
a
# Out:
#      Salary  Employee National Insurance  Income Tax  \
# 236   12572                       360.48         0.4
#
#      Employer National Insurance  Student Loans  Salary Takehome  \
# 236                      515.016            0.0         12211.12
#
#      Total Employee Cost  Usable Funds  Corporation Tax  Dividend  \
# 236            13087.016         37000          4641.32  19786.68
#
#      Dividend Tax  Dividend Takehome  Gross Take  Total Takehome  \
# 236      1334.001          18452.679    32358.68       30663.679
#
#      Percentage Take
# 236        76.659198

# %%
# %%time
b = tax.iterate_lite_full_take(t,e,y,tc,optimal=False)
# Out:
# Wall time: 30.3 s

# %%
b
# Out:
#      Salary  Employee National Insurance  Income Tax  \
# 0     12336                       332.16         0.0
# 1     12337                       332.28         0.0
# 2     12338                       332.40         0.0
# 3     12339                       332.52         0.0
# 4     12340                       332.64         0.0
# ..      ...                          ...         ...
# 510   12846                       393.36        55.2
# 511   12847                       393.48        55.4
# 512   12848                       393.60        55.6
# 513   12849                       393.72        55.8
# 514   12850                       393.84        56.0
#
#      Employer National Insurance  Student Loans  Salary Takehome  \
# 0                        482.448            0.0         12003.84
# 1                        482.586            0.0         12004.72
# 2                        482.724            0.0         12005.60
# 3                        482.862            0.0         12006.48
# 4                        483.000            0.0         12007.36
# ..                           ...            ...              ...
# 510                      552.828            0.0         12397.44
# 511                      552.966            0.0         12398.12
# 512                      553.104            0.0         12398.80
# 513                      553.242            0.0         12399.48
# 514                      553.380            0.0         12400.16
#
#      Total Employee Cost  Usable Funds  Corporation Tax  Dividend  \
# 0              12818.448         37000          4686.16  19977.84
# 1              12819.586         37000          4685.97  19977.03
# 2              12820.724         37000          4685.78  19976.22
# 3              12821.862         37000          4685.59  19975.41
# 4              12823.000         37000          4685.40  19974.60
# ..                   ...           ...              ...       ...
# 510            13398.828         37000          4589.26  19564.74
# 511            13399.966         37000          4589.07  19563.93
# 512            13401.104         37000          4588.88  19563.12
# 513            13402.242         37000          4588.69  19562.31
# 514            13403.380         37000          4588.50  19561.50
#
#      Dividend Tax  Dividend Takehome  Gross Take  Total Takehome  \
# 0      1348.33800        18629.50200    32313.84     30632.50200
# 1      1348.27725        18628.75275    32314.03     30632.75275
# 2      1348.21650        18628.00350    32314.22     30633.00350
# 3      1348.15575        18627.25425    32314.41     30633.25425
# 4      1348.09500        18626.50500    32314.60     30633.50500
# ..            ...                ...         ...             ...
# 510    1317.35550        18247.38450    32410.74     30644.38450
# 511    1317.29475        18246.63525    32410.93     30644.63525
# 512    1317.23400        18245.88600    32411.12     30643.88600
# 513    1317.17325        18245.13675    32411.31     30644.13675
# 514    1317.11250        18244.38750    32411.50     30644.38750
#
#      Percentage Take
# 0          76.581255
# 1          76.581882
# 2          76.582509
# 3          76.583136
# 4          76.583762
# ..               ...
# 510        76.610961
# 511        76.611588
# 512        76.609715
# 513        76.610342
# 514        76.610969
#
# [515 rows x 15 columns]

# %%
t = t
e = e
y = y
tc = tc

funds = t - e
salary_test = 1000

# %%
# %%time
c = tax.ltd_full_take(t,salary_test,e,y,tc)
# Out:
# Wall time: 48 ms

# %%
c
# Out:
#    Salary  Employee National Insurance  Income Tax  \
# 0    1000                          0.0         0.0
#
#    Employer National Insurance  Student Loans  Salary Takehome  \
# 0                          0.0            0.0           1000.0
#
#    Total Employee Cost  Usable Funds  Corporation Tax  Dividend  Dividend Tax  \
# 0               1000.0         37000           6840.0   29160.0       1319.25
#
#    Dividend Takehome  Gross Take  Total Takehome  Percentage Take
# 0           27840.75     30160.0        28840.75        72.101875
