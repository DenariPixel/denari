# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import os
#sys.path.insert(0, os.path.abspath('../denari'))

from denari import tributum as tax
import plotly.graph_objects as go
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 5
#       2 import os
#       3 #sys.path.insert(0, os.path.abspath('../denari'))
# ----> 5 from denari import tributum as tax
#       6 import plotly.graph_objects as go
#
# ImportError: cannot import name 'tributum' from 'denari' (c:\Users\fkarim\AppData\Local\Programs\Python\Python311\Lib\site-packages\denari\__init__.py)

# %%
#dir(tax)

# %%
t = 40000
e = 3000
y = '2021/2022'
tc = '1257A'

# %%
# %%time
a = tax.iterate_lite_full_take(t,e,y,tc)
# Out:
# Wall time: 35.6 s

# %%
a
# Out:
#      Salary  Employee National Insurance  Income Tax  \
# 375   12568                        360.0         0.0
#
#      Employer National Insurance  Student Loans  Salary Takehome  \
# 375                      514.464            0.0          12208.0
#
#      Total Employee Cost  Usable Funds  Corporation Tax     Dividend  \
# 375            13082.464         37000       4544.33184  19373.20416
#
#      Dividend Tax  Dividend Takehome   Gross Take  Total Takehome  \
# 375   1302.990312       18070.213848  31941.20416    30278.213848
#
#      Percentage Take
# 375        75.695535

# %%
# %%time
b = tax.iterate_lite_full_take(t,e,y,tc,optimal=False)
# Out:
# Wall time: 35.3 s

# %%
b
# Out:
#      Salary  Employee National Insurance  Income Tax  \
# 0         0                         0.00         0.0
# 1       257                         0.00         0.0
# 2       514                         0.00         0.0
# 3       771                         0.00         0.0
# 4      1028                         0.00         0.0
# ..      ...                          ...         ...
# 651   12845                       393.24        55.0
# 652   12846                       393.36        55.2
# 653   12847                       393.48        55.4
# 654   12848                       393.60        55.6
# 655   12849                       393.72        55.8
#
#      Employer National Insurance  Student Loans  Salary Takehome  \
# 0                          0.000            0.0             0.00
# 1                          0.000            0.0           257.00
# 2                          0.000            0.0           514.00
# 3                          0.000            0.0           771.00
# 4                          0.000            0.0          1028.00
# ..                           ...            ...              ...
# 651                      552.690            0.0         12396.76
# 652                      552.828            0.0         12397.44
# 653                      552.966            0.0         12398.12
# 654                      553.104            0.0         12398.80
# 655                      553.242            0.0         12399.48
#
#      Total Employee Cost  Usable Funds  Corporation Tax     Dividend  \
# 0                  0.000         37000       7030.00000  29970.00000
# 1                257.000         37000       6981.17000  29761.83000
# 2                514.000         37000       6932.34000  29553.66000
# 3                771.000         37000       6883.51000  29345.49000
# 4               1028.000         37000       6834.68000  29137.32000
# ..                   ...           ...              ...          ...
# 651            13397.690         37000       4484.43890  19117.87110
# 652            13398.828         37000       4484.22268  19116.94932
# 653            13399.966         37000       4484.00646  19116.02754
# 654            13401.104         37000       4483.79024  19115.10576
# 655            13402.242         37000       4483.57402  19114.18398
#
#      Dividend Tax  Dividend Takehome   Gross Take  Total Takehome  \
# 0     1305.000000       28665.000000  29970.00000    28665.000000
# 1     1308.662250       28453.167750  30018.83000    28710.167750
# 2     1312.324500       28241.335500  30067.66000    28755.335500
# 3     1315.986750       28029.503250  30116.49000    28800.503250
# 4     1319.649000       27817.671000  30165.32000    28845.671000
# ..            ...                ...          ...             ...
# 651   1283.840332       17834.030768  31962.87110    30230.030768
# 652   1283.771199       17833.178121  31962.94932    30230.178121
# 653   1283.702065       17832.325474  31963.02754    30230.325474
# 654   1283.632932       17831.472828  31963.10576    30229.472828
# 655   1283.563799       17830.620182  31963.18398    30229.620182
#
#      Percentage Take
# 0          71.662500
# 1          71.775419
# 2          71.888339
# 3          72.001258
# 4          72.114177
# ..               ...
# 651        75.575077
# 652        75.575445
# 653        75.575814
# 654        75.573682
# 655        75.574050
#
# [656 rows x 15 columns]

# %%
t = t
e = e
y = y
tc = tc

funds = t - e
salary_test = 1000

# %%
# %%time
c = tax.ltd_full_take(t,salary_test,e,y,tc)
# Out:
# Wall time: 62.1 ms

# %%
c
# Out:
#    Salary  Employee National Insurance  Income Tax  \
# 0    1000                          0.0         0.0
#
#    Employer National Insurance  Student Loans  Salary Takehome  \
# 0                          0.0            0.0           1000.0
#
#    Total Employee Cost  Usable Funds  Corporation Tax  Dividend  Dividend Tax  \
# 0               1000.0         37000           6840.0   29160.0       1319.25
#
#    Dividend Takehome  Gross Take  Total Takehome  Percentage Take
# 0           27840.75     30160.0        28840.75        72.101875
